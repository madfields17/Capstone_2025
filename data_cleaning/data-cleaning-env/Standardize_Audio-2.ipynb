# %% [markdown]
# !pip install gdown
# !pip install librosa
# !pip install ffmpeg
# !pip install pydub
# !pip install soundfile

# %% [markdown]
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import librosa
from scipy.signal import butter, filtfilt
import numpy as np
import matplotlib.pyplot as plt
import os
import soundfile as sf

# %%
#Download the audio dataset

file_path = '/content/drive/MyDrive/test1'

# !gdown --id
# Out:
# usage: gdown [-h] [-V] [-O OUTPUT] [-q] [--fuzzy] [--id] [--proxy PROXY] [--speed SPEED]
#              [--no-cookies] [--no-check-certificate] [--continue] [--folder] [--remaining-ok]
#              [--format FORMAT] [--user-agent USER_AGENT]
#              url_or_id
# gdown: error: the following arguments are required: url_or_id

# %%
from pydub import AudioSegment
import os

def convert_audio(file_path):
    # Example: If file is not in WAV format, convert it (e.g., MP3 to WAV)
    if file_path.lower().endswith(".mp3"):
        new_file_path = file_path.replace(".mp3", ".wav")
        # Perform conversion (using any library like pydub or ffmpeg for conversion)
        # Placeholder for actual conversion logic
        print(f"Converted and overwrote {file_path} to WAV format")
        return new_file_path
    return file_path

# %%
#Changing the file type to .wav
# !pip install pydub

from os import path
from pydub import AudioSegment


# def convert_to_wav(file_path):
#     file_name, file_extension = os.path.splitext(file_path)

#     #If is wav already then skip
#     if file_extension.lower() == ".wav":
#         return file_path

#     sound = AudioSegment.from_file(file_path)
#     sound.export(file_path, format="wav")
#     return file_path

# %%
#Changing the audio sampling rate
def resample_audio(audio_path, target_sr):
    y, sr = librosa.load(audio_path, sr=None)
    y_resampled = librosa.resample(y, orig_sr=sr, target_sr=target_sr)
    sf.write(audio_path, y_resampled, target_sr)
    return audio_path

# %%
#Convert channels to mono if needed
def convert_to_mono(audio_path):
    y, sr = librosa.load(audio_path, sr=None)
    y_mono = librosa.to_mono(y)
    sf.write(audio_path, y_mono, sr)
    return audio_path

# %%
#Normalizing the volume

def normalize_audio(audio_file):
    audio = AudioSegment.from_file(audio_file)

    normalized_audio = audio.apply_gain(-audio.max_dBFS)  # Normalize to 0 dBFS

    #Export the normalized audio to a temporary file
    temp_file = audio_file.rsplit('.', 1)[0] + '_normalized.wav'
    normalized_audio.export(temp_file, format="wav")
    return temp_file # Return the path to the temporary file

# %%
def trim_silence(audio_file, silence_thresh=-40, silence_len=1000):

    audio = AudioSegment.from_file(audio_file)
    trimmed_audio = audio.strip_silence(silence_thresh=silence_thresh, silence_len=silence_len)
    #Export the trimmed audio back to the original file
    trimmed_audio.export(audio_file, format="wav")
    return audio_file

# %%
#Standardize the duration

def trim_duration(audio, max_duration_ms=5000): #5 sec
    # Check if the audio duration exceeds the max duration
    # Load audio using AudioSegment
    audio_segment = AudioSegment.from_file(audio)
    if len(audio_segment) > max_duration_ms:
        audio_segment = audio_segment[:max_duration_ms]  # Trim the audio to the desired duration
    # Export the trimmed audio back to the original file
    audio_segment.export(audio, format="wav")
    return audio

# %%
#Filter noise if needed
#Filter noise if needed

def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    y = filtfilt(b, a, data)
    return y

# %%
def standardize_audio(audio_path, target_sr=None, lowcut=None, highcut=None, order=5, output_dir=output_dir):
    """Standardizes the audio by applying various transformations and saving the processed files to an output directory."""

    if not os.path.isdir(audio_path):
        print("Invalid input path")
        return

    # Create output directory if it doesn't exist
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
        print(f"Output will be saved to: {output_dir}")

    for filename in os.listdir(audio_path):
        file_path = os.path.join(audio_path, filename)

        if os.path.isfile(file_path):
            print(f"Processing file: {filename}")

            original_file_path = file_path  # Keep track of the original file path
            #Removing the change of the file_path by convert_audio
            convert_audio(file_path)
            # Resample audio if target_sr is provided
            if target_sr:
                resample_audio(file_path, target_sr)
            convert_to_mono(file_path)
            normalize_audio(file_path)
            trim_silence(file_path)
            trim_duration(file_path)


            # Apply bandpass filter if lowcut and highcut are provided
            if lowcut and highcut:
                try:
                    y, sr = librosa.load(file_path, sr=None)
                    filtered_y = butter_bandpass_filter(y, lowcut, highcut, sr, order)

                    output_file = os.path.join(output_dir, filename)
                    sf.write(output_file, filtered_y, sr)
                    print(f"Bandpass filter applied and saved to {output_file}.")
                except Exception as e:
                    print(f"Error applying bandpass filter to {filename}: {e}")
                    continue
            else:
                # If no bandpass filter was applied, save the final processed version (if modified)
                # if new_file_path != original_file_path:  # Only save if modified #This check is no longer needed
                output_file = os.path.join(output_dir, filename)
                shutil.copy(file_path, output_file) #Copying the file to the output_dir as it is if no filters were applied
                print(f"Processed and saved to: {output_file}")

# %%
# Example call to the function
audio_path = 'Unstandardized_full_data/Training'
output_dir = './Standardized_full_data/Training'
target_sr = 16000  # Sample rate
lowcut = 300.0
highcut = 3400.0

standardize_audio(audio_path, target_sr, lowcut, highcut)
# Out:
# Processing file: north_america_v_output_276.mp3
# Converted and overwrote Unstandardized_full_data/Training/north_america_v_output_276.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/north_america_v_output_276.mp3.
# Processing file: africa_v_output_624.mp3
# Converted and overwrote Unstandardized_full_data/Training/africa_v_output_624.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/africa_v_output_624.mp3.
# Processing file: v_output_4677.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4677.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4677.mp3.
# Processing file: v_output_2206.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_2206.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_2206.mp3.
# Processing file: 8c1660ce1c79376ec9e426ff7f9e4b91.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/8c1660ce1c79376ec9e426ff7f9e4b91.wav.
# Processing file: v_output_4111.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4111.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4111.mp3.
# Processing file: file29414.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file29414.wav.
# Processing file: kikongo1.mp3
# Converted and overwrote Unstandardized_full_data/Training/kikongo1.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/kikongo1.mp3.
# Processing file: 53b2a217b8d0ae8f97c7b9992620e5fe.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/53b2a217b8d0ae8f97c7b9992620e5fe.wav.
# Processing file: v_output_1069.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1069.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1069.mp3.
# Processing file: v_output_4105.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4105.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4105.mp3.
# Processing file: africa_v_output_630.mp3
# Converted and overwrote Unstandardized_full_data/Training/africa_v_output_630.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/africa_v_output_630.mp3.
# Processing file: c9998d0dc4f0280ef52b3b6daaf754cd.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/c9998d0dc4f0280ef52b3b6daaf754cd.wav.
# Processing file: v_output_4663.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4663.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4663.mp3.
# Processing file: north_america_v_output_262.mp3
# Converted and overwrote Unstandardized_full_data/Training/north_america_v_output_262.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/north_america_v_output_262.mp3.
# Processing file: file26055.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file26055.wav.
# Processing file: africa_v_output_618.mp3
# Converted and overwrote Unstandardized_full_data/Training/africa_v_output_618.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/africa_v_output_618.mp3.
# Processing file: arabic16.mp3
# Converted and overwrote Unstandardized_full_data/Training/arabic16.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/arabic16.mp3.
# Processing file: v_output_4893.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4893.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4893.mp3.
# Processing file: v_output_1733.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1733.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1733.mp3.
# Processing file: common_voice_en_17666.mp3
# Converted and overwrote Unstandardized_full_data/Training/common_voice_en_17666.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/common_voice_en_17666.mp3.
# Processing file: common_voice_en_17808833.mp3
# Converted and overwrote Unstandardized_full_data/Training/common_voice_en_17808833.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/common_voice_en_17808833.mp3.
# Processing file: v_output_1055.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1055.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1055.mp3.
# Processing file: v_output_5233.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_5233.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_5233.mp3.
# Processing file: v_output_3642.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_3642.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_3642.mp3.
# Processing file: 30c81b6845b3af04ba87400cde06627d.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/30c81b6845b3af04ba87400cde06627d.wav.
# Processing file: v_output_5227.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_5227.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_5227.mp3.
# Processing file: v_output_4139.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4139.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4139.mp3.
# Processing file: v_output_3656.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_3656.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_3656.mp3.
# Processing file: common_voice_en_17808827.mp3
# Converted and overwrote Unstandardized_full_data/Training/common_voice_en_17808827.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/common_voice_en_17808827.mp3.
# Processing file: 3826b0c86c1fc0a4b13024afd5477eb7.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/3826b0c86c1fc0a4b13024afd5477eb7.wav.
# Processing file: v_output_1041.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1041.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1041.mp3.
# Processing file: v_output_1727.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1727.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1727.mp3.
# Processing file: file28044.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file28044.wav.
# Processing file: file31515.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file31515.wav.
# Processing file: file14965.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file14965.wav.
# Processing file: v_output_5541.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_5541.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_5541.mp3.
# Processing file: farsi12.mp3
# Converted and overwrote Unstandardized_full_data/Training/farsi12.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/farsi12.mp3.
# Processing file: v_output_4887.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4887.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4887.mp3.
# Processing file: 8039ef46914f6fcfb21f7c062b010869.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/8039ef46914f6fcfb21f7c062b010869.wav.
# Processing file: v_output_1914.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1914.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1914.mp3.
# Processing file: file28911.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file28911.wav.
# Processing file: fbd226bc5473f0763900e4e8e818c533.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/fbd226bc5473f0763900e4e8e818c533.wav.
# Processing file: v_output_3865.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_3865.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_3865.mp3.
# Processing file: v_output_3871.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_3871.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_3871.mp3.
# Processing file: 00e6182d68f143fb90dcfa8be22af4f4.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/00e6182d68f143fb90dcfa8be22af4f4.wav.
# Processing file: v_output_1900.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1900.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1900.mp3.
# Processing file: v_output_4878.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4878.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4878.mp3.
# Processing file: v_output_1928.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1928.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1928.mp3.
# Processing file: africa_v_output_803.mp3
# Converted and overwrote Unstandardized_full_data/Training/africa_v_output_803.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/africa_v_output_803.mp3.
# Processing file: v_output_4850.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4850.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4850.mp3.
# Processing file: v_output_4688.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4688.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4688.mp3.
# Processing file: v_output_3681.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_3681.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_3681.mp3.
# Processing file: v_output_3859.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_3859.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_3859.mp3.
# Processing file: file18636.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file18636.wav.
# Processing file: v_output_1096.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1096.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1096.mp3.
# Processing file: pashto8.mp3
# Converted and overwrote Unstandardized_full_data/Training/pashto8.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/pashto8.mp3.
# Processing file: v_output_1082.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1082.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1082.mp3.
# Processing file: v_output_3695.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_3695.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_3695.mp3.
# Processing file: africa_v_output_817.mp3
# Converted and overwrote Unstandardized_full_data/Training/africa_v_output_817.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/africa_v_output_817.mp3.
# Processing file: v_output_4844.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4844.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4844.mp3.
# Processing file: file29399.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file29399.wav.
# Processing file: file28087.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file28087.wav.
# Processing file: e1bb317c4dd3fdb78f55eadddcb52e69.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/e1bb317c4dd3fdb78f55eadddcb52e69.wav.
# Processing file: v_output_4313.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4313.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4313.mp3.
# Processing file: d5c1958c54ee13da7a6d0e57248a2a3f.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/d5c1958c54ee13da7a6d0e57248a2a3f.wav.
# Processing file: file15851.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file15851.wav.
# Processing file: v_output_2004.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_2004.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_2004.mp3.
# Processing file: file3101.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file3101.wav.
# Processing file: v_output_4475.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4475.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4475.mp3.
# Processing file: file10929.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file10929.wav.
# Processing file: BI_v_output_468.mp3
# Converted and overwrote Unstandardized_full_data/Training/BI_v_output_468.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/BI_v_output_468.mp3.
# Processing file: v_output_1519.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1519.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1519.mp3.
# Processing file: v_output_2010.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_2010.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_2010.mp3.
# Processing file: v_output_4461.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4461.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4461.mp3.
# Processing file: v_output_3468.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_3468.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_3468.mp3.
# Processing file: v_output_4307.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4307.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4307.mp3.
# Processing file: v_output_5019.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_5019.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_5019.mp3.
# Processing file: 3f6d9fdc91c1bec692f5056320733dc2.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/3f6d9fdc91c1bec692f5056320733dc2.wav.
# Processing file: v_output_3440.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_3440.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_3440.mp3.
# Processing file: v_output_5031.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_5031.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_5031.mp3.
# Processing file: v_output_1257.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1257.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1257.mp3.
# Processing file: BI_v_output_326.mp3
# Converted and overwrote Unstandardized_full_data/Training/BI_v_output_326.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/BI_v_output_326.mp3.
# Processing file: BI_v_output_440.mp3
# Converted and overwrote Unstandardized_full_data/Training/BI_v_output_440.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/BI_v_output_440.mp3.
# Processing file: v_output_1531.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1531.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1531.mp3.
# Processing file: v_output_2038.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_2038.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_2038.mp3.
# Processing file: v_output_4449.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4449.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4449.mp3.
# Processing file: file2237.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file2237.wav.
# Processing file: BI_v_output_454.mp3
# Converted and overwrote Unstandardized_full_data/Training/BI_v_output_454.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/BI_v_output_454.mp3.
# Processing file: v_output_1525.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1525.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1525.mp3.
# Processing file: v_output_1243.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1243.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1243.mp3.
# Processing file: BI_v_output_332.mp3
# Converted and overwrote Unstandardized_full_data/Training/BI_v_output_332.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/BI_v_output_332.mp3.
# Processing file: cb730e7586b20989a20d2a96831c39ce.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/cb730e7586b20989a20d2a96831c39ce.wav.
# Processing file: v_output_3454.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_3454.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_3454.mp3.
# Processing file: v_output_5025.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_5025.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_5025.mp3.
# Processing file: file23475.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file23475.wav.
# Processing file: 000280045.WAV
# Bandpass filter applied and saved to Standardized_full_data/Training/000280045.WAV.
# Processing file: file22958.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file22958.wav.
# Processing file: c5ebd2a85e6bee1655ae7d232f4cdb8d.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/c5ebd2a85e6bee1655ae7d232f4cdb8d.wav.
# Processing file: 58cdf28f31357ab4b02300730eec62a7.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/58cdf28f31357ab4b02300730eec62a7.wav.
# Processing file: file21289.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file21289.wav.
# Processing file: north_america_v1_t_output_254.mp3
# Converted and overwrote Unstandardized_full_data/Training/north_america_v1_t_output_254.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/north_america_v1_t_output_254.mp3.
# Processing file: file15892.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file15892.wav.
# Processing file: north_america_v1_t_output_13.mp3
# Converted and overwrote Unstandardized_full_data/Training/north_america_v1_t_output_13.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/north_america_v1_t_output_13.mp3.
# Processing file: file12131.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file12131.wav.
# Processing file: file4861.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file4861.wav.
# Processing file: 8955febdd0c19ebdb70f1b424ce90533.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/8955febdd0c19ebdb70f1b424ce90533.wav.
# Processing file: north_america_v1_t_output_240.mp3
# Converted and overwrote Unstandardized_full_data/Training/north_america_v1_t_output_240.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/north_america_v1_t_output_240.mp3.
# Processing file: file16431.wav
# Error applying bandpass filter to file16431.wav: The length of the input vector x must be greater than padlen, which is 33.
# Processing file: common_voice_en_17271707.mp3
# Converted and overwrote Unstandardized_full_data/Training/common_voice_en_17271707.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/common_voice_en_17271707.mp3.
# Processing file: v_output_1294.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1294.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1294.mp3.
# Processing file: file13561.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file13561.wav.
# Processing file: v_output_3483.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_3483.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_3483.mp3.
# Processing file: 260aa44b0a382e2599e8906910329a32.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/260aa44b0a382e2599e8906910329a32.wav.
# Processing file: BI_v_output_483.mp3
# Converted and overwrote Unstandardized_full_data/Training/BI_v_output_483.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/BI_v_output_483.mp3.
# Processing file: BI_v_output_497.mp3
# Converted and overwrote Unstandardized_full_data/Training/BI_v_output_497.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/BI_v_output_497.mp3.
# Processing file: v_output_3497.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_3497.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_3497.mp3.
# Processing file: v_output_1280.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1280.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1280.mp3.
# Processing file: file29825.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file29825.wav.
# Processing file: dd28731291981c509146de8daf9e422e.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/dd28731291981c509146de8daf9e422e.wav.
# Processing file: v_output_5179.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_5179.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_5179.mp3.
# Processing file: v_output_4267.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4267.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4267.mp3.
# Processing file: v_output_3508.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_3508.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_3508.mp3.
# Processing file: africa_v_output_552.mp3
# Converted and overwrote Unstandardized_full_data/Training/africa_v_output_552.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/africa_v_output_552.mp3.
# Processing file: v_output_4501.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4501.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4501.mp3.
# Processing file: v_output_2170.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_2170.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_2170.mp3.
# Processing file: file5404.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file5404.wav.
# Processing file: v_output_1479.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1479.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1479.mp3.
# Processing file: BI_v_output_508.mp3
# Converted and overwrote Unstandardized_full_data/Training/BI_v_output_508.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/BI_v_output_508.mp3.
# Processing file: 62700b056394213c67310cffb77f0763.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/62700b056394213c67310cffb77f0763.wav.
# Processing file: file8134.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file8134.wav.
# Processing file: africa_v_output_546.mp3
# Converted and overwrote Unstandardized_full_data/Training/africa_v_output_546.mp3 to WAV format
# Error applying bandpass filter to africa_v_output_546.mp3: The length of the input vector x must be greater than padlen, which is 33.
# Processing file: v_output_4515.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4515.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4515.mp3.
# Processing file: v_output_2164.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_2164.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_2164.mp3.
# Processing file: v_output_4273.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4273.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4273.mp3.
# Processing file: file8652.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file8652.wav.
# Processing file: v_output_5145.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_5145.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_5145.mp3.
# Processing file: v_output_3534.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_3534.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_3534.mp3.
# Processing file: common_voice_en_17271698.mp3
# Converted and overwrote Unstandardized_full_data/Training/common_voice_en_17271698.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/common_voice_en_17271698.mp3.
# Processing file: v_output_1323.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1323.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1323.mp3.
# Processing file: v_output_1445.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1445.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1445.mp3.
# Processing file: file15919.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file15919.wav.
# Processing file: v_output_4529.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4529.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4529.mp3.
# Processing file: v_output_2158.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_2158.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_2158.mp3.
# Processing file: v_output_1451.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1451.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1451.mp3.
# Processing file: file9216.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file9216.wav.
# Processing file: file27001.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file27001.wav.
# Processing file: file31663.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file31663.wav.
# Processing file: v_output_1337.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1337.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1337.mp3.
# Processing file: v_output_5151.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_5151.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_5151.mp3.
# Processing file: v_output_3520.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_3520.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_3520.mp3.
# Processing file: file4054.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file4054.wav.
# Processing file: common_voice_en_17787312.mp3
# Converted and overwrote Unstandardized_full_data/Training/common_voice_en_17787312.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/common_voice_en_17787312.mp3.
# Processing file: file24285.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file24285.wav.
# Processing file: 8cc39f302d01f5a4a88dac69928a7996.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/8cc39f302d01f5a4a88dac69928a7996.wav.
# Processing file: africa_v_output_591.mp3
# Converted and overwrote Unstandardized_full_data/Training/africa_v_output_591.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/africa_v_output_591.mp3.
# Processing file: africa_v_output_585.mp3
# Converted and overwrote Unstandardized_full_data/Training/africa_v_output_585.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/africa_v_output_585.mp3.
# Processing file: d3dbdae803f2fda94e29fe5a13027a57.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/d3dbdae803f2fda94e29fe5a13027a57.wav.
# Processing file: file27940.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file27940.wav.
# Processing file: file24291.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file24291.wav.
# Processing file: 37743c37454fd283a089160b44ff4961.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/37743c37454fd283a089160b44ff4961.wav.
# Processing file: BI_v_output_291.mp3
# Converted and overwrote Unstandardized_full_data/Training/BI_v_output_291.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/BI_v_output_291.mp3.
# Processing file: v_output_4298.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4298.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4298.mp3.
# Processing file: v_output_5186.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_5186.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_5186.mp3.
# Processing file: c4917b212f78d80b2fbb27fb90acd292.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/c4917b212f78d80b2fbb27fb90acd292.wav.
# Processing file: v_output_1486.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1486.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1486.mp3.
# Processing file: v_output_1492.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1492.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1492.mp3.
# Processing file: v_output_5192.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_5192.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_5192.mp3.
# Processing file: BI_v_output_285.mp3
# Converted and overwrote Unstandardized_full_data/Training/BI_v_output_285.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/BI_v_output_285.mp3.
# Processing file: file29789.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file29789.wav.
# Processing file: file6858.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file6858.wav.
# Processing file: v_output_4703.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4703.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4703.mp3.
# Processing file: africa_v_output_750.mp3
# Converted and overwrote Unstandardized_full_data/Training/africa_v_output_750.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/africa_v_output_750.mp3.
# Processing file: file4518.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file4518.wav.
# Processing file: v_output_4065.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4065.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4065.mp3.
# Processing file: v_output_2414.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_2414.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_2414.mp3.
# Processing file: file6469.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file6469.wav.
# Processing file: v_output_1109.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1109.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1109.mp3.
# Processing file: common_voice_en_17776658.mp3
# Converted and overwrote Unstandardized_full_data/Training/common_voice_en_17776658.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/common_voice_en_17776658.mp3.
# Processing file: common_voice_en_17816589.mp3
# Converted and overwrote Unstandardized_full_data/Training/common_voice_en_17816589.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/common_voice_en_17816589.mp3.
# Processing file: v_output_4071.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4071.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4071.mp3.
# Processing file: v_output_2400.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_2400.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_2400.mp3.
# Processing file: v_output_5409.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_5409.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_5409.mp3.
# Processing file: v_output_4717.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4717.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4717.mp3.
# Processing file: africa_v_output_744.mp3
# Converted and overwrote Unstandardized_full_data/Training/africa_v_output_744.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/africa_v_output_744.mp3.
# Processing file: north_america_v_output_316.mp3
# Converted and overwrote Unstandardized_full_data/Training/north_america_v_output_316.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/north_america_v_output_316.mp3.
# Processing file: v_output_5421.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_5421.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_5421.mp3.
# Processing file: v_output_1647.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1647.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1647.mp3.
# Processing file: v_output_1121.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1121.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1121.mp3.
# Processing file: 100130036.WAV
# Bandpass filter applied and saved to Standardized_full_data/Training/100130036.WAV.
# Processing file: v_output_3736.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_3736.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_3736.mp3.
# Processing file: v_output_4059.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4059.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4059.mp3.
# Processing file: v_output_5347.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_5347.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_5347.mp3.
# Processing file: v_output_3722.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_3722.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_3722.mp3.
# Processing file: v_output_5353.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_5353.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_5353.mp3.
# Processing file: v_output_1135.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1135.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1135.mp3.
# Processing file: 100130022.WAV
# Bandpass filter applied and saved to Standardized_full_data/Training/100130022.WAV.
# Processing file: common_voice_en_17706.mp3
# Converted and overwrote Unstandardized_full_data/Training/common_voice_en_17706.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/common_voice_en_17706.mp3.
# Processing file: v_output_1653.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1653.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1653.mp3.
# Processing file: file23065.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file23065.wav.
# Processing file: v_output_5435.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_5435.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_5435.mp3.
# Processing file: common_voice_en_17822176.mp3
# Converted and overwrote Unstandardized_full_data/Training/common_voice_en_17822176.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/common_voice_en_17822176.mp3.
# Processing file: africa_v_output_778.mp3
# Converted and overwrote Unstandardized_full_data/Training/africa_v_output_778.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/africa_v_output_778.mp3.
# Processing file: africa_v_output_793.mp3
# Converted and overwrote Unstandardized_full_data/Training/africa_v_output_793.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/africa_v_output_793.mp3.
# Processing file: file12253.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file12253.wav.
# Processing file: v_output_4918.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4918.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4918.mp3.
# Processing file: file30794.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file30794.wav.
# Processing file: north_america_v1_t_output_122.mp3
# Converted and overwrote Unstandardized_full_data/Training/north_america_v1_t_output_122.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/north_america_v1_t_output_122.mp3.
# Processing file: file21699.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file21699.wav.
# Processing file: v_output_1860.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1860.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1860.mp3.
# Processing file: 4604bee1adaa752ec0952f13a65876be.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/4604bee1adaa752ec0952f13a65876be.wav.
# Processing file: v_output_3911.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_3911.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_3911.mp3.
# Processing file: f3f1163ca0645f76ee681c15052a7e54.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/f3f1163ca0645f76ee681c15052a7e54.wav.
# Processing file: v_output_3905.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_3905.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_3905.mp3.
# Processing file: file10336.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file10336.wav.
# Processing file: v_output_1874.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1874.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1874.mp3.
# Processing file: africa_v_output_787.mp3
# Converted and overwrote Unstandardized_full_data/Training/africa_v_output_787.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/africa_v_output_787.mp3.
# Processing file: file10478.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file10478.wav.
# Processing file: v_output_1684.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1684.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1684.mp3.
# Processing file: v_output_4924.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4924.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4924.mp3.
# Processing file: 48d1f4069e985b45cb64342979f504e1.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/48d1f4069e985b45cb64342979f504e1.wav.
# Processing file: v_output_5384.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_5384.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_5384.mp3.
# Processing file: v_output_3939.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_3939.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_3939.mp3.
# Processing file: v_output_5390.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_5390.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_5390.mp3.
# Processing file: c1aac7a90536f0a9f354df67e62eeb9b.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/c1aac7a90536f0a9f354df67e62eeb9b.wav.
# Processing file: v_output_2399.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_2399.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_2399.mp3.
# Processing file: v_output_4930.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4930.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4930.mp3.
# Processing file: v_output_1690.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1690.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1690.mp3.
# Processing file: v_output_1848.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1848.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1848.mp3.
# Processing file: v_output_5391.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_5391.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_5391.mp3.
# Processing file: v_output_3938.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_3938.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_3938.mp3.
# Processing file: file32814.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file32814.wav.
# Processing file: file474.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file474.wav.
# Processing file: v_output_1849.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1849.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1849.mp3.
# Processing file: v_output_1691.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1691.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1691.mp3.
# Processing file: 264119b658475193b757257052e76023.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/264119b658475193b757257052e76023.wav.
# Processing file: v_output_4931.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4931.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4931.mp3.
# Processing file: v_output_2398.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_2398.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_2398.mp3.
# Processing file: v_output_4925.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4925.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4925.mp3.
# Processing file: 6a30d015da14c79869c576b4f9963647.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/6a30d015da14c79869c576b4f9963647.wav.
# Processing file: 9b896a134c32994968c7a4f6d961acb2.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/9b896a134c32994968c7a4f6d961acb2.wav.
# Processing file: file11767.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file11767.wav.
# Processing file: v_output_1685.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1685.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1685.mp3.
# Processing file: file11001.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file11001.wav.
# Processing file: v_output_5385.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_5385.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_5385.mp3.
# Processing file: 6d6dd86423cbfbaf1b65080755890e14.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/6d6dd86423cbfbaf1b65080755890e14.wav.
# Processing file: v_output_3904.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_3904.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_3904.mp3.
# Processing file: africa_v_output_786.mp3
# Converted and overwrote Unstandardized_full_data/Training/africa_v_output_786.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/africa_v_output_786.mp3.
# Processing file: v_output_1875.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1875.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1875.mp3.
# Processing file: v_output_1861.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1861.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1861.mp3.
# Processing file: north_america_v1_t_output_123.mp3
# Converted and overwrote Unstandardized_full_data/Training/north_america_v1_t_output_123.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/north_america_v1_t_output_123.mp3.
# ...
# Processing file: v_output_3794.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_3794.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_3794.mp3.
# Processing file: file18723.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file18723.wav.
# Processing file: v_output_1183.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1183.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1183.mp3.
# Processing file: common_voice_en_17270726.mp3
# Converted and overwrote Unstandardized_full_data/Training/common_voice_en_17270726.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/common_voice_en_17270726.mp3.
# Processing file: mankanya1.mp3
# Converted and overwrote Unstandardized_full_data/Training/mankanya1.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/mankanya1.mp3.
# Processing file: common_voice_en_17270732.mp3
# Converted and overwrote Unstandardized_full_data/Training/common_voice_en_17270732.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/common_voice_en_17270732.mp3.
# Processing file: v_output_1197.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1197.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1197.mp3.
# Processing file: file9908.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file9908.wav.
# Processing file: 439a64f9f655384209023b021ecb8f23.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/439a64f9f655384209023b021ecb8f23.wav.
# Processing file: v_output_3780.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_3780.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_3780.mp3.
# Processing file: v_output_3958.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_3958.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_3958.mp3.
# Processing file: 41834ce25cc1413095fde8bcdc2cdb5e.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/41834ce25cc1413095fde8bcdc2cdb5e.wav.
# Processing file: v_output_5497.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_5497.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_5497.mp3.
# Processing file: africa_v_output_902.mp3
# Converted and overwrote Unstandardized_full_data/Training/africa_v_output_902.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/africa_v_output_902.mp3.
# Processing file: v_output_4951.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4951.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4951.mp3.
# Processing file: v_output_4789.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4789.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4789.mp3.
# Processing file: v_output_1829.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1829.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1829.mp3.
# Processing file: v_output_977.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_977.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_977.mp3.
# Processing file: 6d37d029e29fad64a5ced28b727344e8.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/6d37d029e29fad64a5ced28b727344e8.wav.
# Processing file: v_output_4979.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4979.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4979.mp3.
# Processing file: v_output_1801.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1801.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1801.mp3.
# Processing file: v_output_3970.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_3970.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_3970.mp3.
# Processing file: v_output_3964.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_3964.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_3964.mp3.
# Processing file: 3e47be2488c6a9fca6ae69cad43cfc50.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/3e47be2488c6a9fca6ae69cad43cfc50.wav.
# Processing file: v_output_1815.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1815.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1815.mp3.
# Processing file: 501c0c7b41a5145d240d6ecc6c1b49dd.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/501c0c7b41a5145d240d6ecc6c1b49dd.wav.
# Processing file: north_america_v1_t_output_157.mp3
# Converted and overwrote Unstandardized_full_data/Training/north_america_v1_t_output_157.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/north_america_v1_t_output_157.mp3.
# Processing file: v_output_963.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_963.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_963.mp3.
# Processing file: common_voice_en_17881657.mp3
# Converted and overwrote Unstandardized_full_data/Training/common_voice_en_17881657.mp3 to WAV format
# Error applying bandpass filter to common_voice_en_17881657.mp3: The length of the input vector x must be greater than padlen, which is 33.
# Processing file: 8ebdead47a6da8b224ac880979fc33fd.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/8ebdead47a6da8b224ac880979fc33fd.wav.
# Processing file: file5868.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file5868.wav.
# Processing file: v_output_5440.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_5440.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_5440.mp3.
# Processing file: v_output_988.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_988.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_988.mp3.
# Processing file: v_output_4986.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4986.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4986.mp3.
# Processing file: v_output_1626.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1626.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1626.mp3.
# Processing file: common_voice_en_17773.mp3
# Converted and overwrote Unstandardized_full_data/Training/common_voice_en_17773.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/common_voice_en_17773.mp3.
# Processing file: 9ed990473c6f8584687a5c45c308c6c7.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/9ed990473c6f8584687a5c45c308c6c7.wav.
# Processing file: v_output_1140.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1140.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1140.mp3.
# Processing file: v_output_5326.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_5326.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_5326.mp3.
# Processing file: v_output_4038.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4038.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4038.mp3.
# Processing file: v_output_3757.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_3757.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_3757.mp3.
# Processing file: v_output_5332.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_5332.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_5332.mp3.
# Processing file: v_output_3743.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_3743.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_3743.mp3.
# Processing file: v_output_1154.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1154.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1154.mp3.
# Processing file: v_output_1632.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1632.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1632.mp3.
# Processing file: africa_v_output_719.mp3
# Converted and overwrote Unstandardized_full_data/Training/africa_v_output_719.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/africa_v_output_719.mp3.
# Processing file: common_voice_en_17822117.mp3
# Converted and overwrote Unstandardized_full_data/Training/common_voice_en_17822117.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/common_voice_en_17822117.mp3.
# Processing file: v_output_5454.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_5454.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_5454.mp3.
# Processing file: v_output_4992.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4992.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4992.mp3.
# Processing file: north_america_v_output_363.mp3
# Converted and overwrote Unstandardized_full_data/Training/north_america_v_output_363.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/north_america_v_output_363.mp3.
# Processing file: north_america_v1_t_output_180.mp3
# Converted and overwrote Unstandardized_full_data/Training/north_america_v1_t_output_180.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/north_america_v1_t_output_180.mp3.
# Processing file: file28179.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file28179.wav.
# Processing file: file4579.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file4579.wav.
# Processing file: africa_v_output_731.mp3
# Converted and overwrote Unstandardized_full_data/Training/africa_v_output_731.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/africa_v_output_731.mp3.
# Processing file: v_output_4762.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4762.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4762.mp3.
# Processing file: file34236.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file34236.wav.
# Processing file: v_output_4004.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4004.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4004.mp3.
# Processing file: file18910.wav
# Bandpass filter applied and saved to Standardized_full_data/Training/file18910.wav.
# Processing file: v_output_1168.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_1168.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_1168.mp3.
# Processing file: v_output_4010.mp3
# Converted and overwrote Unstandardized_full_data/Training/v_output_4010.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/v_output_4010.mp3.
# Processing file: africa_v_output_725.mp3
# Converted and overwrote Unstandardized_full_data/Training/africa_v_output_725.mp3 to WAV format
# Bandpass filter applied and saved to Standardized_full_data/Training/africa_v_output_725.mp3.
# Processing file: 02cf0fd41613b1de96e1902f90e8d1eb.wav
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 8
#       5 lowcut = 300.0
#       6 highcut = 3400.0
# ----> 8 standardize_audio(audio_path, target_sr, lowcut, highcut)
#
# Cell In[14], line 27, in standardize_audio(audio_path, target_sr, lowcut, highcut, order, output_dir)
#      25 convert_to_mono(file_path)
#      26 normalize_audio(file_path)
# ---> 27 trim_silence(file_path)
#      28 trim_duration(file_path)
#      31 # Apply bandpass filter if lowcut and highcut are provided
#
# Cell In[8], line 4, in trim_silence(audio_file, silence_thresh, silence_len)
#       1 def trim_silence(audio_file, silence_thresh=-40, silence_len=1000):
#       3     audio = AudioSegment.from_file(audio_file)
# ----> 4     trimmed_audio = audio.strip_silence(silence_thresh=silence_thresh, silence_len=silence_len)
#       5     #Export the trimmed audio back to the original file
#       6     trimmed_audio.export(audio_file, format="wav")
#
# File ~/Library/Caches/pypoetry/virtualenvs/data-cleaning-y4n0my6I-py3.9/lib/python3.9/site-packages/pydub/effects.py:102, in strip_silence(seg, silence_len, silence_thresh, padding)
#      99 if padding > silence_len:
#     100     raise InvalidDuration("padding cannot be longer than silence_len")
# --> 102 chunks = split_on_silence(seg, silence_len, silence_thresh, padding)
#     103 crossfade = padding / 2
#     105 if not len(chunks):
#
# File ~/Library/Caches/pypoetry/virtualenvs/data-cleaning-y4n0my6I-py3.9/lib/python3.9/site-packages/pydub/silence.py:150, in split_on_silence(audio_segment, min_silence_len, silence_thresh, keep_silence, seek_step)
#     144 if isinstance(keep_silence, bool):
#     145     keep_silence = len(audio_segment) if keep_silence else 0
#     147 output_ranges = [
#     148     [ start - keep_silence, end + keep_silence ]
#     149     for (start,end)
# --> 150         in detect_nonsilent(audio_segment, min_silence_len, silence_thresh, seek_step)
#     151 ]
#     153 for range_i, range_ii in pairwise(output_ranges):
#     154     last_end = range_i[1]
#
# File ~/Library/Caches/pypoetry/virtualenvs/data-cleaning-y4n0my6I-py3.9/lib/python3.9/site-packages/pydub/silence.py:86, in detect_nonsilent(audio_segment, min_silence_len, silence_thresh, seek_step)
#      76 def detect_nonsilent(audio_segment, min_silence_len=1000, silence_thresh=-16, seek_step=1):
#      77     """
#      78     Returns a list of all nonsilent sections [start, end] in milliseconds of audio_segment.
#      79     Inverse of detect_silent()
#    (...)
#      84     seek_step - step size for interating over the segment in ms
#      85     """
# ---> 86     silent_ranges = detect_silence(audio_segment, min_silence_len, silence_thresh, seek_step)
#      87     len_seg = len(audio_segment)
#      89     # if there is no silence, the whole thing is nonsilent
#
# File ~/Library/Caches/pypoetry/virtualenvs/data-cleaning-y4n0my6I-py3.9/lib/python3.9/site-packages/pydub/silence.py:43, in detect_silence(audio_segment, min_silence_len, silence_thresh, seek_step)
#      41 for i in slice_starts:
#      42     audio_slice = audio_segment[i:i + min_silence_len]
# ---> 43     if audio_slice.rms <= silence_thresh:
#      44         silence_starts.append(i)
#      46 # short circuit when there is no silence
#
# File ~/Library/Caches/pypoetry/virtualenvs/data-cleaning-y4n0my6I-py3.9/lib/python3.9/site-packages/pydub/audio_segment.py:1086, in AudioSegment.rms(self)
#    1084 @property
#    1085 def rms(self):
# -> 1086     return audioop.rms(self._data, self.sample_width)
#
# KeyboardInterrupt:

# %%
import os
import shutil
import librosa
import soundfile as sf
from multiprocessing import Pool, cpu_count
from pathlib import Path
from functools import partial

# Define your utility functions here (convert_audio, resample_audio, normalize_audio, etc.)

def process_single_file(filename, input_dir, output_dir, target_sr, lowcut, highcut, order):
    input_path = os.path.join(input_dir, filename)
    output_path = os.path.join(output_dir, filename)

    if not os.path.isfile(input_path):
        return

    # ✅ Skip if file already processed
    if os.path.exists(output_path):
        print(f"Skipping (already processed): {filename}")
        return

    try:
        print(f"Processing: {filename}")
        convert_audio(input_path)

        if target_sr:
            resample_audio(input_path, target_sr)

        convert_to_mono(input_path)
        normalize_audio(input_path)
        trim_silence(input_path)
        trim_duration(input_path)

        if lowcut and highcut:
            y, sr = librosa.load(input_path, sr=None)
            filtered_y = butter_bandpass_filter(y, lowcut, highcut, sr, order)
            sf.write(output_path, filtered_y, sr)
        else:
            shutil.copy(input_path, output_path)

        print(f"✅ Saved: {output_path}")
    except Exception as e:
        print(f"❌ Error processing {filename}: {e}")

def standardize_audio_parallel(audio_path, target_sr=None, lowcut=None, highcut=None, order=5, output_dir="standardized_audio"):
    if not os.path.isdir(audio_path):
        print("Invalid input path")
        return

    os.makedirs(output_dir, exist_ok=True)

    files = os.listdir(audio_path)
    num_workers = min(cpu_count() - 2, 6)
    print(num_workers)

    with Pool(num_workers) as pool:
        pool.map(partial(
            process_single_file,
            input_dir=audio_path,
            output_dir=output_dir,
            target_sr=target_sr,
            lowcut=lowcut,
            highcut=highcut,
            order=order
        ), files)

    print("🎉 All done!")

# %%
standardize_audio_parallel(
    audio_path='Unstandardized_full_data/Training',
    target_sr=16000,
    lowcut=300.0,
    highcut=3400.0,
    output_dir='./Standardized_full_data/Training'
)
# Out:
# 6
# Process SpawnPoolWorker-2:
# Process SpawnPoolWorker-4:
# Process SpawnPoolWorker-3:
# Process SpawnPoolWorker-1:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/queues.py", line 368, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_single_file' on <module '__main__' (built-in)>
# Traceback (most recent call last):
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/queues.py", line 368, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_single_file' on <module '__main__' (built-in)>
# Traceback (most recent call last):
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/queues.py", line 368, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_single_file' on <module '__main__' (built-in)>
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/queues.py", line 368, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_single_file' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-5:
# Traceback (most recent call last):
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/queues.py", line 368, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_single_file' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-6:
# Traceback (most recent call last):
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/queues.py", line 368, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_single_file' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-7:
# Traceback (most recent call last):
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/queues.py", line 368, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_single_file' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-8:
# Traceback (most recent call last):
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/queues.py", line 368, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_single_file' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-9:
# Traceback (most recent call last):
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/queues.py", line 368, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_single_file' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-10:
# Traceback (most recent call last):
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/queues.py", line 368, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_single_file' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-11:
# Traceback (most recent call last):
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/queues.py", line 368, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_single_file' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-12:
# Traceback (most recent call last):
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/queues.py", line 368, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_single_file' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-13:
# Traceback (most recent call last):
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/queues.py", line 368, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_single_file' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-14:
# Traceback (most recent call last):
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/queues.py", line 368, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_single_file' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-15:
# Traceback (most recent call last):
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/queues.py", line 368, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_single_file' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-16:
# Traceback (most recent call last):
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/queues.py", line 368, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_single_file' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-17:
# Traceback (most recent call last):
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/queues.py", line 368, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_single_file' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-18:
# Traceback (most recent call last):
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/queues.py", line 368, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_single_file' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-19:
# Traceback (most recent call last):
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/queues.py", line 368, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_single_file' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-20:
# Traceback (most recent call last):
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/queues.py", line 368, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_single_file' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-21:
# Traceback (most recent call last):
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/queues.py", line 368, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_single_file' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-22:
# Traceback (most recent call last):
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/queues.py", line 368, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_single_file' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-23:
# Traceback (most recent call last):
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/queues.py", line 368, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_single_file' on <module '__main__' (built-in)>
# Process SpawnPoolWorker-24:
# Traceback (most recent call last):
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/alecnaidoo/miniforge3/lib/python3.9/multiprocessing/queues.py", line 368, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'process_single_file' on <module '__main__' (built-in)>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 standardize_audio_parallel(
#       2     audio_path='Unstandardized_full_data/Training',
#       3     target_sr=16000,
#       4     lowcut=300.0,
#       5     highcut=3400.0,
#       6     output_dir='./Standardized_full_data/Training'
#       7 )
#
# Cell In[18], line 58, in standardize_audio_parallel(audio_path, target_sr, lowcut, highcut, order, output_dir)
#      55 print(num_workers)
#      57 with Pool(num_workers) as pool:
# ---> 58     pool.map(partial(
#      59         process_single_file,
#      60         input_dir=audio_path,
#      61         output_dir=output_dir,
#      62         target_sr=target_sr,
#      63         lowcut=lowcut,
#      64         highcut=highcut,
#      65         order=order
#      66     ), files)
#      68 print("🎉 All done!")
#
# File ~/miniforge3/lib/python3.9/multiprocessing/pool.py:364, in Pool.map(self, func, iterable, chunksize)
#     359 def map(self, func, iterable, chunksize=None):
#     360     '''
#     361     Apply `func` to each element in `iterable`, collecting the results
#     362     in a list that is returned.
#     363     '''
# --> 364     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/miniforge3/lib/python3.9/multiprocessing/pool.py:765, in ApplyResult.get(self, timeout)
#     764 def get(self, timeout=None):
# --> 765     self.wait(timeout)
#     766     if not self.ready():
#     767         raise TimeoutError
#
# File ~/miniforge3/lib/python3.9/multiprocessing/pool.py:762, in ApplyResult.wait(self, timeout)
#     761 def wait(self, timeout=None):
# --> 762     self._event.wait(timeout)
#
# File ~/miniforge3/lib/python3.9/threading.py:574, in Event.wait(self, timeout)
#     572 signaled = self._flag
#     573 if not signaled:
# --> 574     signaled = self._cond.wait(timeout)
#     575 return signaled
#
# File ~/miniforge3/lib/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:
